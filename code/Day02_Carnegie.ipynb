# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanaxiom/Applied-ML/blob/main/code/Carnegie_Day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Student Instructions**: Before you begin, click **File > Save a copy in Drive** so you do not lose your work!

# %%
import pandas as pd
import numpy as np

url = ("https://raw.githubusercontent.com/ryanaxiom/Applied-ML/main/data/carnegie_data.csv")

carnegie = pd.read_csv(url, encoding="cp1252")

# %%
print(carnegie.shape)
display(carnegie)
print(carnegie.columns)
carnegie.dtypes
# Out:
# (3939, 101)
#       unitid                                     name        city stabbr  \
# 0     177834  A T Still University of Health Sciences  Kirksville     MO
# 1     180203                   Aaniiih Nakoda College      Harlem     MT
# 2     222178             Abilene Christian University     Abilene     TX
# 3     138558     Abraham Baldwin Agricultural College      Tifton     GA
# 4     488031               Abraham Lincoln University    Glendale     CA
# ...      ...                                      ...         ...    ...
# 3934  206695              Youngstown State University  Youngstown     OH
# 3935  375939             YTI Career Institute-Altoona     Altoona     PA
# 3936  217077                YTI Career Institute-York        York     PA
# 3937  126119                             Yuba College  Marysville     CA
# 3938  204255                       Zane State College  Zanesville     OH
#
#       basic2000  basic2005  basic2010  basic2015  basic2018  basic2021  ...  \
# ...

# %%
carnegie["totdeg"][[0,20,50,3000]]
# Out:
# 0       1056
# 20        51
# 50       602
# 3000     572
# Name: totdeg, dtype: int64

# %%
carnegie[["name","stabbr","totdeg"]]
# Out:
#                                          name stabbr  totdeg
# 0     A T Still University of Health Sciences     MO    1056
# 1                      Aaniiih Nakoda College     MT      32
# 2                Abilene Christian University     TX    1286
# 3        Abraham Baldwin Agricultural College     GA     715
# 4                  Abraham Lincoln University     CA      31
# ...                                       ...    ...     ...
# 3934              Youngstown State University     OH    2375
# 3935             YTI Career Institute-Altoona     PA      20
# 3936                YTI Career Institute-York     PA     167
# 3937                             Yuba College     CA     812
# 3938                       Zane State College     OH     285
#
# [3939 rows x 3 columns]

# %%
carnegie[carnegie["control"] == 1]
# Out:
#       unitid                                  name          city stabbr  \
# 1     180203                Aaniiih Nakoda College        Harlem     MT
# 3     138558  Abraham Baldwin Agricultural College        Tifton     GA
# 13    126182                Adams State University       Alamosa     CO
# 24    217615               Aiken Technical College  Graniteville     SC
# 25    126207                Aims Community College       Greeley     CO
# ...      ...                                   ...           ...    ...
# 3929  420440         York County Community College         Wells     ME
# 3930  218991                York Technical College     Rock Hill     SC
# 3934  206695           Youngstown State University    Youngstown     OH
# 3937  126119                          Yuba College    Marysville     CA
# 3938  204255                    Zane State College    Zanesville     OH
#
#       basic2000  basic2005  basic2010  basic2015  basic2018  basic2021  ...  \
# ...

# %%
carnegie[carnegie["totdeg"] > 5000]
# Out:
#       unitid                                        name            city  \
# 27    999911                              Air University      Montgomery
# 98    449339           American Public University System    Charles Town
# 134   197869                Appalachian State University           Boone
# 145   104151   Arizona State University Campus Immersion           Tempe
# 146   483124  Arizona State University Digital Immersion      Scottsdale
# ...      ...                                         ...             ...
# 3730  172644                      Wayne State University         Detroit
# 3735  230782                      Weber State University           Ogden
# 3774  238032                    West Virginia University      Morgantown
# 3783  433387                Western Governors University  Salt Lake City
# 3787  172699                 Western Michigan University       Kalamazoo
#
#      stabbr  basic2000  basic2005  basic2010  basic2015  basic2018  basic2021  \
# ...

# %%
carnegie.iloc[0:5]
# Out:
#    unitid                                     name        city stabbr  \
# 0  177834  A T Still University of Health Sciences  Kirksville     MO
# 1  180203                   Aaniiih Nakoda College      Harlem     MT
# 2  222178             Abilene Christian University     Abilene     TX
# 3  138558     Abraham Baldwin Agricultural College      Tifton     GA
# 4  488031               Abraham Lincoln University    Glendale     CA
#
#    basic2000  basic2005  basic2010  basic2015  basic2018  basic2021  ...  \
# 0         52         25         25         25         25         25  ...
# 1         60         33         33         33         33         33  ...
# 2         21         19         19         18         18         17  ...
# 3         40          2          2         23         23         23  ...
# 4         -2         -2         -2         -2         31         31  ...
#
#    satv25  satm25  satcmb25  actcmp25  satacteq25   actfinal  appsf20  \
# ...

# %%
carnegie["totdeg"].describe()
# Out:
# count     3939.000000
# mean      1082.136075
# std       2263.824902
# min          0.000000
# 25%         95.000000
# 50%        365.000000
# 75%        991.000000
# max      42484.000000
# Name: totdeg, dtype: float64

# %%
carnegie["control"].value_counts()
# Out:
# control
# 2    1666
# 1    1628
# 3     645
# Name: count, dtype: int64

# %%
print(carnegie["totdeg"].mean())
print(carnegie["totdeg"].median())
carnegie["totdeg"].std()
# Out:
# 1082.136075145976
# 365.0
# 2263.824901943425

# %%
carnegie["name"].value_counts()
# Out:
# name
# Columbia College                        4
# Union College                           4
# Southwestern College                    3
# Lincoln University                      3
# Bethel University                       3
#                                        ..
# Hagerstown Community College            1
# Halifax Community College               1
# Hallmark University                     1
# Hamilton College                        1
# Guilford Technical Community College    1
# Name: count, Length: 3895, dtype: int64

# %%
carnegie["research"] = carnegie["serd"] + carnegie["nonserd"]
y = carnegie["research"].dropna()
y.shape
# Out:
# (302,)
